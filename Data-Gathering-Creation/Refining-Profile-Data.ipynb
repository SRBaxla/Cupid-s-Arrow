# %% [markdown]
# # Refining Profile Data
# Adding information to the categories

# %% [markdown]
# ### Library and Data Imports

# %%
import pandas as pd
import _pickle as pickle
import numpy as np
from scipy.stats import halfnorm

# %%
with open("profiles.pkl",'rb') as fp:
    df = pickle.load(fp)

# %%
# Removing the numerical data
df = df[['Bios']]

# %% [markdown]
# ### Creating Lists for the Categories

# %%
# Probability dictionary
p = {}

#Gender
gender = ['male','female']
p['Gender'] = [0.5,0.5]

# Movie Genres
movies = ['Adventure',
          'Action',
          'Drama',
          'Comedy',
          'Thriller',
          'Horror',
          'RomCom',
          'Musical',
          'Documentary']

p['Movies'] = [0.28,
               0.21,
               0.16,
               0.14,
               0.09,
               0.06,
               0.04,
               0.01, 
               0.01]

# TV Genres
tv = ['Comedy',
      'Drama',
      'Action/Adventure',
      'Suspense/Thriller',
      'Documentaries',
      'Crime/Mystery',
      'News',
      'SciFi',
      'History']

p['TV'] = [0.30,
           0.23,
           0.12,
           0.12,
           0.09,
           0.08,
           0.03,
           0.02,
           0.01]

# Religions (could potentially create a spectrum)
religion = ['Catholic',
            'Christian',
            'Jewish',
            'Muslim',
            'Hindu',
            'Buddhist',
            'Spiritual',
            'Other',
            'Agnostic',
            'Atheist']

p['Religion'] = [0.16,
                 0.16,
                 0.01,
                 0.19,
                 0.11,
                 0.05,
                 0.10,
                 0.09,
                 0.07,
                 0.06]

# Music
music = ['Rock',
         'HipHop',
         'Pop',
         'Country',
         'Latin',
         'EDM',
         'Gospel',
         'Jazz',
         'Classical']

p['Music'] = [0.30,
              0.23,
              0.20,
              0.10,
              0.06,
              0.04,
              0.03,
              0.02,
              0.02]

# Sports
sports = ['Football',
          'Baseball',
          'Basketball',
          'Hockey',
          'Soccer',
          'Other']

p['Sports'] = [0.34,
               0.30,
               0.16, 
               0.13,
               0.04,
               0.03]

# Politics (could also put on a spectrum)
politics = ['Liberal',
            'Progressive',
            'Centrist',
            'Moderate',
            'Conservative']

p['Politics'] = [0.26,
                 0.11,
                 0.11,
                 0.15,
                 0.37]

# Social Media
social = ['Facebook',
          'Youtube',
          'Twitter',
          'Reddit',
          'Instagram',
          'Pinterest',
          'LinkedIn',
          'SnapChat',
          'TikTok']

p['Social Media'] = [0.36,
                     0.27,
                     0.11,
                     0.09,
                     0.05,
                     0.03,
                     0.03,
                     0.03,
                     0.03]

# Age (generating random numbers based on half normal distribution)
age = halfnorm.rvs(loc=18,scale=8, size=df.shape[0]).astype(int)

# Lists of Names and the list of the lists
categories = [gender, movies, religion, music, politics, social, sports, age]

names = ['Gender','Movies','Religion', 'Music', 'Politics', 'Social Media', 'Sports', 'Age']

combined = dict(zip(names, categories))

# %% [markdown]
# ### Establishing random values for each category

# %%
# Looping through and assigning random values
for name, cats in combined.items():
    if name in ['Religion', 'Politics','Gender']:
        # Picking only 1 from the list
        df[name] = np.random.choice(cats, df.shape[0], p=p[name])
        
    elif name == 'Age':
        # Generating random ages based on a normal distribution
        df[name] = cats
    else:
        # Picking 3 from the list 
        try:
            df[name] = list(np.random.choice(cats, size=(df.shape[0],1,3), p=p[name]))
        except:
            df[name] = list(np.random.choice(cats, size=(df.shape[0],1,3)))
        
        df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))

# %%
df.head(20)
# Out:
#                                                  Bios  Gender  \
# 0   Evil communicator. Avid analyst. Freelance gam...  female
# 1   Alcohol lover. Evil analyst. Infuriatingly hum...  female
# 2   Amateur pop culture ninja. Social media expert...    male
# 3   Wannabe baconaholic. Music evangelist. Hardcor...    male
# 4   Wannabe creator. Student. Social media enthusi...    male
# 5   Beer trailblazer. Avid troublemaker. Pop cultu...  female
# 6   Infuriatingly humble coffee geek. Music enthus...    male
# 7   Extreme coffee evangelist. Social media enthus...    male
# 8   Hardcore social media fanatic. Extreme coffee ...  female
# 9   Hipster-friendly alcoholaholic. Music speciali...  female
# 10  Evil pop culture lover. Passionate travel advo...  female
# 11  Amateur writer. Internet maven. Food fan. Typi...  female
# 12  Award-winning coffeeaholic. Introvert. Lifelon...    male
# 13  Avid writer. Food buff. Tv evangelist. Freelan...    male
# 14  Total student. Award-winning social media love...    male
# 15  Evil communicator. Avid analyst. Freelance gam...  female
# 16  Alcohol lover. Evil analyst. Infuriatingly hum...    male
# 17  Amateur pop culture ninja. Social media expert...  female
# 18  Wannabe baconaholic. Music evangelist. Hardcor...  female
# 19  Wannabe creator. Student. Social media enthusi...    male
#
#                            Movies   Religion                    Music  \
# 0             [Adventure, Action]      Other           [Rock, HipHop]
# 1      [Adventure, Drama, Action]  Christian           [Rock, HipHop]
# 2                 [RomCom, Drama]     Muslim              [Pop, Rock]
# 3       [Thriller, Drama, Action]     Muslim     [Jazz, HipHop, Rock]
# 4     [Comedy, Adventure, RomCom]  Christian      [Pop, Rock, HipHop]
# 5      [Adventure, Drama, Action]   Agnostic      [HipHop, Classical]
# 6         [Horror, RomCom, Drama]  Spiritual       [Pop, Rock, Latin]
# 7   [Comedy, Documentary, Action]     Muslim  [Country, HipHop, Rock]
# 8              [Adventure, Drama]     Muslim              [Pop, Rock]
# 9      [Comedy, Thriller, Action]   Catholic          [HipHop, Latin]
# 10      [Thriller, Drama, Action]   Catholic           [Rock, HipHop]
# 11       [Horror, Comedy, Action]   Agnostic      [Pop, Rock, Gospel]
# 12       [Horror, Comedy, RomCom]      Other      [Pop, Rock, HipHop]
# 13               [Comedy, Action]      Other         [HipHop, Gospel]
# 14              [Thriller, Drama]      Hindu     [Pop, Country, Rock]
# 15            [Adventure, Action]   Buddhist  [Country, HipHop, Rock]
# 16  [Thriller, Adventure, Action]  Christian     [Pop, Country, Rock]
# 17               [Horror, Action]   Agnostic           [Rock, HipHop]
# 18               [Comedy, Action]      Other     [Country, Rock, EDM]
# 19    [RomCom, Adventure, Action]      Hindu    [Pop, HipHop, Gospel]
#
#         Politics                    Social Media  \
# 0       Moderate               [TikTok, Twitter]
# 1   Conservative     [Youtube, Reddit, Facebook]
# 2        Liberal    [Facebook, Youtube, Twitter]
# 3        Liberal      [Youtube, Reddit, Twitter]
# 4   Conservative   [Youtube, Facebook, SnapChat]
# 5       Centrist  [Pinterest, Youtube, LinkedIn]
# 6       Centrist   [Youtube, Facebook, LinkedIn]
# 7    Progressive  [LinkedIn, Twitter, Pinterest]
# 8        Liberal             [Youtube, Facebook]
# 9        Liberal            [Youtube, Instagram]
# 10  Conservative     [Reddit, Facebook, Twitter]
# 11       Liberal             [Youtube, Facebook]
# 12      Moderate   [LinkedIn, Facebook, Twitter]
# 13  Conservative             [Youtube, Facebook]
# 14       Liberal                       [Youtube]
# 15       Liberal  [LinkedIn, Youtube, Pinterest]
# 16  Conservative     [Youtube, Reddit, Facebook]
# 17  Conservative    [Youtube, Twitter, SnapChat]
# 18       Liberal               [Youtube, Reddit]
# 19   Progressive                      [Facebook]
#
#                               Sports  Age
# 0   [Basketball, Baseball, Football]   19
# 1                         [Football]   18
# 2             [Basketball, Football]   20
# 3                 [Hockey, Football]   19
# 4         [Baseball, Hockey, Soccer]   22
# 5                 [Football, Soccer]   22
# 6               [Baseball, Football]   18
# 7     [Baseball, Basketball, Soccer]   24
# 8                 [Baseball, Hockey]   19
# 9   [Basketball, Baseball, Football]   20
# 10              [Baseball, Football]   23
# 11    [Baseball, Basketball, Soccer]   22
# 12            [Baseball, Basketball]   25
# 13                [Baseball, Soccer]   35
# 14  [Basketball, Baseball, Football]   27
# 15  [Basketball, Baseball, Football]   25
# 16      [Baseball, Hockey, Football]   18
# 17         [Other, Hockey, Football]   20
# 18            [Basketball, Football]   18
# 19    [Basketball, Hockey, Football]   19

# %% [markdown]
# ### Categorizing

# %%
df['Religion'] = pd.Categorical(df.Religion, ordered=True,
                                categories=['Catholic',
                                            'Christian',
                                            'Jewish',
                                            'Muslim',
                                            'Hindu',
                                            'Buddhist',
                                            'Spiritual',
                                            'Other',
                                            'Agnostic',
                                            'Atheist'])

df['Politics'] = pd.Categorical(df.Politics, ordered=True,
                                categories=['Liberal',
                                            'Progressive',
                                            'Centrist',
                                            'Moderate',
                                            'Conservative'])

# %% [markdown]
# ### Exporting the DF

# %%
with open("refined_profiles.pkl",'wb') as fp:
    pickle.dump(df, fp)
